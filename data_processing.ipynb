# %% [markdown]
# # Final Project Sketch

# %% [markdown]
# In this notebook I will be adding pieces of code / ideas periodically that may be helpful for your final project.
# It is in no way meant to be something to copy/paste and use directly. Feel free to use as much or as little of it
# as you please.

# %% [markdown]
# ## 1. Big Query Data Gathering

# %% [markdown]
# First you need to go to
# https://cloud.google.com/docs/authentication/getting-started to set up an account and an API key. Follow the instructions and then
#     replace the link below with the JSON file that gets downloaded.

# %%
import pandas as pd
import os

pd.set_option('display.max_columns', 500)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="./My First Project-ebcdd06f0c10.json"

# %% [markdown]
# ## 1.2 Compute time bewteen pickup and dropoff.

# %%
from google.cloud import bigquery
client = bigquery.Client()


query = (
    """SELECT *,
    TIMESTAMP_DIFF( dropoff_datetime, pickup_datetime, SECOND) as travel_time,
    EXTRACT (DATE FROM pickup_datetime) as date_of_year
    FROM `bigquery-public-data.new_york.tlc_yellow_trips_2016`
    LIMIT 100"""
)
df=pd.io.gbq.read_gbq(query,dialect='standard')

# %%
df.head()
# Out:
#   vendor_id           pickup_datetime          dropoff_datetime  \
# 0         2 2016-01-09 18:45:41+00:00 2016-01-09 19:27:06+00:00
# 1         2 2016-08-11 09:42:47+00:00 2016-08-11 10:27:56+00:00
# 2         2 2016-05-29 07:06:29+00:00 2016-05-29 07:21:58+00:00
# 3         1 2016-09-12 05:27:15+00:00 2016-09-12 05:45:19+00:00
# 4         1 2016-04-18 11:44:03+00:00 2016-04-18 12:14:19+00:00
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1          14.73        -73.781914        40.644855
# 1                1           3.64               NaN              NaN
# 2                1           8.73        -73.957191        40.699409
# 3                1          10.00               NaN              NaN
# 4                1           7.40        -73.885345        40.773102
#
#    rate_code store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0          1                  N         -73.923454         40.761738
# 1          1                  N                NaN               NaN
# 2          1                  N         -73.914413         40.779861
# 3          1                  N                NaN               NaN
# 4          1                  N         -73.963440         40.803619
#
#   payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0            1         45.0    0.0      0.5        9.16          0.00
# 1            1         26.5    0.0      0.5        6.82          0.00
# 2            1         25.5    0.0      0.5        7.89          0.00
# 3            1         27.5    0.5      0.5        6.85          5.54
# 4            1         27.5    0.0      0.5        6.75          5.54
#
#    imp_surcharge  total_amount  travel_time date_of_year
# 0            0.3         54.96         2485   2016-01-09
# 1            0.3         34.12         2709   2016-08-11
# 2            0.3         34.19          929   2016-05-29
# 3            0.3         41.19         1084   2016-09-12
# 4            0.3         40.59         1816   2016-04-18

# %% [markdown]
# Here we join with the publicly available weather data. This isn't required, but the goal here is just to show you what's posisble
# with big query. Spend some time exploring the public data and coming up with hypotheses!

# %%
query = (
    """
    SELECT * FROM 
    (
    SELECT *,
    TIMESTAMP_DIFF( dropoff_datetime, pickup_datetime, SECOND) as travel_time,
     EXTRACT (DATE FROM pickup_datetime) as date_of_year,
     EXTRACT (DAY FROM pickup_datetime) as day_of_year,
     EXTRACT (MONTH FROM pickup_datetime) as month_of_year,
     EXTRACT (YEAR FROM pickup_datetime) as year_of_year
    FROM `bigquery-public-data.new_york.tlc_yellow_trips_2016` ) a 
    INNER JOIN
    (
     select concat(year,'-',mo,'-',da) as date_of_year2,year,mo,da,temp,visib,wdsp,gust,max,min,prcp,sndp,fog,rain_drizzle,snow_ice_pellets,hail,thunder
     from `bigquery-public-data.noaa_gsod.gsod2016` where stn='010090'
    ) weather_data
    on CAST(a.date_of_year AS STRING) = weather_data.date_of_year2
    LIMIT 200000"""
)
df=pd.io.gbq.read_gbq(query,dialect='standard')

# %%
df.head()
# Out:
#   vendor_id           pickup_datetime          dropoff_datetime  \
# 0         2 2016-04-19 03:23:30+00:00 2016-04-19 03:52:34+00:00
# 1         2 2016-10-21 22:45:39+00:00 2016-10-21 23:15:53+00:00
# 2         1 2016-08-01 07:09:11+00:00 2016-08-01 07:09:22+00:00
# 3         2 2016-08-20 07:26:04+00:00 2016-08-20 08:16:57+00:00
# 4         1 2016-07-23 09:58:46+00:00 2016-07-23 10:23:39+00:00
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1           9.12        -73.997597        40.756592
# 1                2          10.73               NaN              NaN
# 2                1           0.00               NaN              NaN
# 3                1          13.48               NaN              NaN
# 4                1           5.50               NaN              NaN
#
#    rate_code store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0          1                  N          -73.99794          40.75668
# 1          1                  N                NaN               NaN
# 2          1                  N                NaN               NaN
# 3          1                  N                NaN               NaN
# 4          1                  N                NaN               NaN
#
#   payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0            1         29.5    0.5      0.5        1.00           0.0
# 1            1         33.0    0.5      0.5        6.86           0.0
# 2            2          2.5    0.0      0.5        0.00           0.0
# 3            2         48.5    0.0      0.5        0.00           0.0
# 4            2         23.0    0.0      0.5        0.00           0.0
#
#    imp_surcharge  total_amount  travel_time date_of_year  day_of_year  \
# 0            0.3         31.80         1744   2016-04-19           19
# 1            0.3         41.16         1814   2016-10-21           21
# 2            0.3          3.30           11   2016-08-01            1
# 3            0.3         49.30         3053   2016-08-20           20
# 4            0.3         23.80         1493   2016-07-23           23
#
#    month_of_year  year_of_year date_of_year2  year  mo  da  temp  visib  wdsp  \
# 0              4          2016    2016-04-19  2016  04  19  20.8  999.9  20.9
# 1             10          2016    2016-10-21  2016  10  21  36.2  999.9  23.0
# 2              8          2016    2016-08-01  2016  08  01  34.2  999.9  10.6
# 3              8          2016    2016-08-20  2016  08  20  38.1  999.9   7.7
# 4              7          2016    2016-07-23  2016  07  23  40.0  999.9   8.8
#
#     gust   max   min  prcp   sndp fog rain_drizzle snow_ice_pellets hail  \
# 0  999.9  23.0  14.9   0.0  999.9   0            0                0    0
# 1  999.9  43.0  27.1   0.0  999.9   0            0                0    0
# 2  999.9  35.6  32.2   0.0  999.9   0            0                0    0
# 3  999.9  41.2  35.1   0.0  999.9   0            0                0    0
# 4  999.9  43.7  37.2   0.0  999.9   0            0                0    0
#
#   thunder
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Data integrity checks

# %%
# Remove missing values
print('Original data size: ',len(df))
df = df.dropna()
print('After filter with NaN:', len(df))
df.head()
# Out:
# Original data size:  200000
# After filter with NaN: 105991
#   vendor_id           pickup_datetime          dropoff_datetime  \
# 0         2 2016-04-19 03:23:30+00:00 2016-04-19 03:52:34+00:00
# 5         2 2016-03-21 06:45:31+00:00 2016-03-21 07:08:16+00:00
# 6         1 2016-01-12 08:26:57+00:00 2016-01-12 09:02:51+00:00
# 8         2 2016-06-26 20:11:33+00:00 2016-06-26 20:11:38+00:00
# 9         2 2016-02-09 22:25:37+00:00 2016-02-09 22:26:01+00:00
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1           9.12        -73.997597        40.756592
# 5                1          11.32        -73.776741        40.645466
# 6                2           6.30        -74.000999        40.710278
# 8                1           0.00        -73.781906        40.644543
# 9                6           0.00        -74.063126        40.613476
#
#    rate_code store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0          1                  N         -73.997940         40.756680
# 5          1                  N         -73.709724         40.746422
# 6          1                  N         -73.976265         40.783081
# 8          1                  N         -73.781868         40.644447
# 9          1                  N           0.000000          0.000000
#
#   payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0            1         29.5    0.5      0.5        1.00           0.0
# 5            1         31.0    0.0      0.5        6.36           0.0
# 6            1         28.0    0.0      0.5        1.00           0.0
# 8            2          2.5    0.5      0.5        0.00           0.0
# 9            2          2.5    0.5      0.5        0.00           0.0
#
#    imp_surcharge  total_amount  travel_time date_of_year  day_of_year  \
# 0            0.3         31.80         1744   2016-04-19           19
# 5            0.3         38.16         1365   2016-03-21           21
# 6            0.3         29.80         2154   2016-01-12           12
# 8            0.3          3.80            5   2016-06-26           26
# 9            0.3          3.80           24   2016-02-09            9
#
#    month_of_year  year_of_year date_of_year2  year  mo  da  temp  visib  wdsp  \
# 0              4          2016    2016-04-19  2016  04  19  20.8  999.9  20.9
# 5              3          2016    2016-03-21  2016  03  21   5.5  999.9  16.8
# 6              1          2016    2016-01-12  2016  01  12  21.3  999.9   3.8
# 8              6          2016    2016-06-26  2016  06  26  36.7  999.9   5.7
# 9              2          2016    2016-02-09  2016  02  09  22.0  999.9  25.8
#
#     gust   max   min  prcp   sndp fog rain_drizzle snow_ice_pellets hail  \
# 0  999.9  23.0  14.9   0.0  999.9   0            0                0    0
# 5  999.9   8.1   3.4   0.0  999.9   0            0                0    0
# 6  999.9  24.1  18.9   0.0  999.9   0            0                0    0
# 8  999.9  41.7  34.3   0.0  999.9   0            0                0    0
# 9  999.9  25.7  15.8   0.0  999.9   0            0                0    0
#
#   thunder
# 0       0
# 5       0
# 6       0
# 8       0
# 9       0

# %% [markdown]
# ## Visualize the features of each value

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

focused_features = ['pickup_longitude', 'pickup_latitude','dropoff_longitude','dropoff_latitude',\
                    'passenger_count', 'trip_distance',\
                    'rate_code', 'payment_type','fare_amount','extra', \
                    'mta_tax', 'tip_amount','tolls_amount','imp_surcharge', \
                    'total_amount', 'travel_time','temp', 'visib','wdsp','gust',\
                    'fog', 'max', 'min','rain_drizzle','snow_ice_pellets','store_and_fwd_flag',\
                    'vendor_id', 'prcp','sndp','hail', 'thunder'\
                   ]

rows = len(focused_features)
plt.figure(figsize=(16,rows*2))
for idx, feature in enumerate(focused_features):
    plt.subplot(rows,1,idx+1)
    plt.scatter(df['date_of_year'], df[feature], s=2, label=str(idx)+' '+feature)
    plt.legend()

# %% [markdown]
# ## Filter noise for each feature according to the observations above

# %%
filters = {}
# filters[i] =(min, max) : remove ith feature with min/max filter
filters[0] = (-100, -50)
filters[1] = (20, 70)
filters[2] = (-100, -50)
filters[3] = (20, 70)
filters[4] = (1, 7)
filters[5] = (0, 70)
filters[6] = (0,50)
filters[8] = (0,1000)
filters[9] = (-2, 2)
filters[10] = (-0.5,0.5)
filters[11] = (0, 100)
filters[12] = (-20, 200)
filters[14] = (0, 1000)
filters[15] = (0, 36000)
filters[19] = (500,2000)
bools = df['pickup_longitude'] > -1000

for k, v in filters.items():
    bools = bools & (df[focused_features[k]] >= v[0]) & (df[focused_features[k]]<=v[1])
df = df[bools]
print(len(df))
# Out:
# 49208

# %%
plt.scatter(df['date_of_year'], df['store_and_fwd_flag'], s=2, label=str(0)+' store_and_fwd_flag')
plt.legend()

# %% [markdown]
# ## 1.2 Compute haversine distance between pickup and dropoff

# %%
from google.cloud import bigquery
client = bigquery.Client()


query = (
    """
CREATE TEMP FUNCTION RADIANS(x FLOAT64) AS (
  ACOS(-1) * x / 180
);
CREATE TEMP FUNCTION RADIANS_TO_KM(x FLOAT64) AS (
  111.045 * 180 * x / ACOS(-1)
);
CREATE TEMP FUNCTION HAVERSINE(lat1 FLOAT64, long1 FLOAT64,
                               lat2 FLOAT64, long2 FLOAT64) AS (
  RADIANS_TO_KM(
    ACOS(COS(RADIANS(lat1)) * COS(RADIANS(lat2)) *
         COS(RADIANS(long1) - RADIANS(long2)) +
         SIN(RADIANS(lat1)) * SIN(RADIANS(lat2))))
);

SELECT
  pickup_latitude,
  pickup_longitude,
  TIMESTAMP_DIFF( dropoff_datetime, pickup_datetime, SECOND) as travel_time,
  HAVERSINE(dropoff_latitude,dropoff_longitude, pickup_latitude, pickup_longitude) AS distance_in_km
FROM `nyc-tlc.yellow.trips`
WHERE pickup_latitude IS NOT NULL AND pickup_longitude IS NOT NULL and dropoff_longitude IS NOT NULL and HAVERSINE(dropoff_latitude,dropoff_longitude, pickup_latitude, pickup_longitude)>0.1 LIMIT 100;
"""
)
df2=pd.io.gbq.read_gbq(query,dialect='standard')

# %%
df2.head()
# Out:
#    pickup_latitude  pickup_longitude  travel_time  distance_in_km
# 0        40.757960        -73.987630           35        1.240719
# 1        40.758817        -73.984630          843        3.473030
# 2        40.771859        -73.871434          321        1.183891
# 3         0.000000          0.000000           12     8650.632979
# 4        40.699852        -74.133125            6        0.117585

# %%
# %matplotlib inline

# %% [markdown]
# # 2. Remove outliers and filter data

# %%
df_filtered=df[(df['travel_time']>0) & (df['distance_in_km']<50)  & (df['travel_time']<1000)]

# %%
df_filtered.plot(x='distance_in_km',y='travel_time',kind='scatter')

# %% [markdown]
# # 3. Build a model and evaluate it

# %% [markdown]
# Test Train Split

# %%
import numpy as np
from sklearn.model_selection import train_test_split
y = df_filtered['travel_time']
X = df_filtered['distance_in_km']

X=np.matrix(X).reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %% [markdown]
# **Random forest model**

# %%
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

rf_clf = RandomForestClassifier(n_estimators=100,
                             random_state=0)




rf_clf.fit(X_train,y_train)
rf_clf.score(X_test,y_test)
# Out:
# 0.0625

# %% [markdown]
# `rf_clf.score` is actually the $R^2$ score (see documentation)

# %% [markdown]
# **Linear model**

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.model_selection import train_test_split
y = df_filtered['travel_time']
X = df_filtered['distance_in_km']
X=np.matrix(X).reshape(-1,1)
linear_clf = LinearRegression()


linear_clf.fit(X_train,y_train)
linear_clf.score(X_test,y_test)
# Out:
# 0.5061546907399057
